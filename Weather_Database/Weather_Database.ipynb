# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import requests

# %%
from citipy import citipy

# %%
from datetime import datetime

# %%
# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=37cdbe8ee84d2e90132ae5124aaf9491

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 779

# %%
city_url = url + "&q=" + "Boston"
city_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=37cdbe8ee84d2e90132ae5124aaf9491&q=Boston'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description,
                          "Date": city_date})
        
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nikolskoye
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | masallatah
# Processing Record 4 of Set 1 | lodja
# Processing Record 5 of Set 1 | sao joao da barra
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | ponta delgada
# Processing Record 8 of Set 1 | drumheller
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | bubaque
# Processing Record 11 of Set 1 | tara
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | wanning
# Processing Record 14 of Set 1 | roald
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 1 | qiqihar
# Processing Record 18 of Set 1 | lebu
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | kalianget
# Processing Record 21 of Set 1 | tetouan
# Processing Record 22 of Set 1 | chuy
# Processing Record 23 of Set 1 | okha
# Processing Record 24 of Set 1 | leningradskiy
# Processing Record 25 of Set 1 | kerteminde
# Processing Record 26 of Set 1 | port-cartier
# Processing Record 27 of Set 1 | saint-joseph
# Processing Record 28 of Set 1 | isangel
# Processing Record 29 of Set 1 | lazaro cardenas
# Processing Record 30 of Set 1 | mahaicony
# City not found. Skipping...
# Processing Record 31 of Set 1 | east london
# Processing Record 32 of Set 1 | okhotsk
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | esperance
# Processing Record 37 of Set 1 | vestmannaeyjar
# Processing Record 38 of Set 1 | beloha
# Processing Record 39 of Set 1 | kavieng
# Processing Record 40 of Set 1 | walvis bay
# Processing Record 41 of Set 1 | bandiagara
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | fort nelson
# Processing Record 44 of Set 1 | alofi
# Processing Record 45 of Set 1 | honiara
# Processing Record 46 of Set 1 | chalus
# Processing Record 47 of Set 1 | chokurdakh
# Processing Record 48 of Set 1 | faanui
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | houma
# Processing Record 1 of Set 2 | stropkov
# Processing Record 2 of Set 2 | tieling
# Processing Record 3 of Set 2 | alice springs
# Processing Record 4 of Set 2 | north battleford
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 2 | thompson
# Processing Record 8 of Set 2 | korla
# Processing Record 9 of Set 2 | torbay
# Processing Record 10 of Set 2 | mazagao
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | mahibadhoo
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 2 | ushuaia
# Processing Record 17 of Set 2 | bredasdorp
# Processing Record 18 of Set 2 | new norfolk
# Processing Record 19 of Set 2 | sitka
# Processing Record 20 of Set 2 | methoni
# Processing Record 21 of Set 2 | bac lieu
# Processing Record 22 of Set 2 | batemans bay
# Processing Record 23 of Set 2 | parana
# Processing Record 24 of Set 2 | taksimo
# Processing Record 25 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 2 | saint anthony
# Processing Record 27 of Set 2 | wau
# Processing Record 28 of Set 2 | mayo
# Processing Record 29 of Set 2 | lagoa
# Processing Record 30 of Set 2 | ilhabela
# Processing Record 31 of Set 2 | saldanha
# Processing Record 32 of Set 2 | jiangyou
# Processing Record 33 of Set 2 | tasiilaq
# Processing Record 34 of Set 2 | saskylakh
# Processing Record 35 of Set 2 | hirado
# Processing Record 36 of Set 2 | rio gallegos
# Processing Record 37 of Set 2 | port blair
# Processing Record 38 of Set 2 | lethem
# Processing Record 39 of Set 2 | poum
# Processing Record 40 of Set 2 | rikitea
# Processing Record 41 of Set 2 | verkhnevilyuysk
# Processing Record 42 of Set 2 | kautokeino
# Processing Record 43 of Set 2 | grand gaube
# Processing Record 44 of Set 2 | atuona
# Processing Record 45 of Set 2 | hermanus
# Processing Record 46 of Set 2 | port elizabeth
# Processing Record 47 of Set 2 | riyadh
# Processing Record 48 of Set 2 | asau
# Processing Record 49 of Set 2 | kapaa
# Processing Record 50 of Set 2 | vaitape
# Processing Record 1 of Set 3 | yellowknife
# Processing Record 2 of Set 3 | lompoc
# Processing Record 3 of Set 3 | castro
# Processing Record 4 of Set 3 | nola
# Processing Record 5 of Set 3 | klaksvik
# Processing Record 6 of Set 3 | nabire
# Processing Record 7 of Set 3 | cooma
# Processing Record 8 of Set 3 | saint-philippe
# Processing Record 9 of Set 3 | kodiak
# Processing Record 10 of Set 3 | montepuez
# Processing Record 11 of Set 3 | butaritari
# Processing Record 12 of Set 3 | codrington
# Processing Record 13 of Set 3 | victoria
# Processing Record 14 of Set 3 | bengkulu
# Processing Record 15 of Set 3 | garden city
# Processing Record 16 of Set 3 | fortuna
# Processing Record 17 of Set 3 | caborca
# Processing Record 18 of Set 3 | skjervoy
# Processing Record 19 of Set 3 | maku
# Processing Record 20 of Set 3 | hithadhoo
# Processing Record 21 of Set 3 | laukaa
# Processing Record 22 of Set 3 | tuktoyaktuk
# Processing Record 23 of Set 3 | naze
# Processing Record 24 of Set 3 | saint-georges
# Processing Record 25 of Set 3 | nanortalik
# Processing Record 26 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 3 | tiksi
# Processing Record 28 of Set 3 | sechura
# Processing Record 29 of Set 3 | buala
# Processing Record 30 of Set 3 | matara
# Processing Record 31 of Set 3 | nantucket
# Processing Record 32 of Set 3 | emba
# Processing Record 33 of Set 3 | san andres
# Processing Record 34 of Set 3 | mar del plata
# Processing Record 35 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 3 | mahebourg
# Processing Record 37 of Set 3 | havelock
# Processing Record 38 of Set 3 | fayaoue
# Processing Record 39 of Set 3 | severo-kurilsk
# Processing Record 40 of Set 3 | qeshm
# Processing Record 41 of Set 3 | issoire
# Processing Record 42 of Set 3 | karratha
# Processing Record 43 of Set 3 | gardendale
# Processing Record 44 of Set 3 | upernavik
# Processing Record 45 of Set 3 | dikson
# Processing Record 46 of Set 3 | kanchanaburi
# Processing Record 47 of Set 3 | sahuaripa
# Processing Record 48 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 3 | adrar
# Processing Record 50 of Set 3 | teguldet
# Processing Record 1 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 4 | surt
# Processing Record 3 of Set 4 | sorland
# Processing Record 4 of Set 4 | bontang
# Processing Record 5 of Set 4 | tezu
# Processing Record 6 of Set 4 | sarakhs
# Processing Record 7 of Set 4 | bethel
# Processing Record 8 of Set 4 | aswan
# Processing Record 9 of Set 4 | aksu
# Processing Record 10 of Set 4 | bambous virieux
# Processing Record 11 of Set 4 | norman wells
# Processing Record 12 of Set 4 | belgrade
# Processing Record 13 of Set 4 | pathein
# Processing Record 14 of Set 4 | ridgecrest
# Processing Record 15 of Set 4 | hobyo
# Processing Record 16 of Set 4 | quatre cocos
# Processing Record 17 of Set 4 | northam
# Processing Record 18 of Set 4 | moerai
# Processing Record 19 of Set 4 | virginia beach
# Processing Record 20 of Set 4 | rosetta
# Processing Record 21 of Set 4 | kalmunai
# Processing Record 22 of Set 4 | pangnirtung
# Processing Record 23 of Set 4 | newport
# Processing Record 24 of Set 4 | sri aman
# Processing Record 25 of Set 4 | puerto ayora
# Processing Record 26 of Set 4 | ancud
# Processing Record 27 of Set 4 | vanimo
# Processing Record 28 of Set 4 | sehwan
# Processing Record 29 of Set 4 | jinchang
# Processing Record 30 of Set 4 | belyy yar
# Processing Record 31 of Set 4 | kaitangata
# Processing Record 32 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 4 | auki
# Processing Record 34 of Set 4 | maceio
# Processing Record 35 of Set 4 | uglovka
# Processing Record 36 of Set 4 | westport
# Processing Record 37 of Set 4 | carnarvon
# Processing Record 38 of Set 4 | anderson
# Processing Record 39 of Set 4 | san quintin
# Processing Record 40 of Set 4 | bonthe
# Processing Record 41 of Set 4 | jiaojiang
# Processing Record 42 of Set 4 | karapyshi
# Processing Record 43 of Set 4 | iwaki
# Processing Record 44 of Set 4 | saint-francois
# Processing Record 45 of Set 4 | tashtyp
# Processing Record 46 of Set 4 | cayenne
# Processing Record 47 of Set 4 | lugovoy
# Processing Record 48 of Set 4 | guerrero negro
# Processing Record 49 of Set 4 | labuhan
# Processing Record 50 of Set 4 | lorengau
# Processing Record 1 of Set 5 | vao
# Processing Record 2 of Set 5 | ixtapa
# Processing Record 3 of Set 5 | lima
# Processing Record 4 of Set 5 | tuatapere
# Processing Record 5 of Set 5 | port hedland
# Processing Record 6 of Set 5 | barguzin
# Processing Record 7 of Set 5 | kondinskoye
# Processing Record 8 of Set 5 | bukama
# Processing Record 9 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 5 | synya
# Processing Record 11 of Set 5 | surab
# Processing Record 12 of Set 5 | umm lajj
# Processing Record 13 of Set 5 | byron bay
# Processing Record 14 of Set 5 | porto san giorgio
# Processing Record 15 of Set 5 | jijiga
# Processing Record 16 of Set 5 | santa cruz
# Processing Record 17 of Set 5 | pevek
# Processing Record 18 of Set 5 | ust-maya
# Processing Record 19 of Set 5 | cabo san lucas
# Processing Record 20 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 21 of Set 5 | banda aceh
# Processing Record 22 of Set 5 | dire dawa
# Processing Record 23 of Set 5 | ozu
# Processing Record 24 of Set 5 | altus
# Processing Record 25 of Set 5 | hindupur
# Processing Record 26 of Set 5 | te anau
# Processing Record 27 of Set 5 | pedasi
# Processing Record 28 of Set 5 | honolulu
# Processing Record 29 of Set 5 | ulladulla
# Processing Record 30 of Set 5 | tilichiki
# Processing Record 31 of Set 5 | port alfred
# Processing Record 32 of Set 5 | marawi
# Processing Record 33 of Set 5 | paamiut
# Processing Record 34 of Set 5 | nanzhang
# Processing Record 35 of Set 5 | kurumkan
# Processing Record 36 of Set 5 | iqaluit
# Processing Record 37 of Set 5 | alausi
# Processing Record 38 of Set 5 | arraial do cabo
# Processing Record 39 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 40 of Set 5 | tahta
# Processing Record 41 of Set 5 | metro
# Processing Record 42 of Set 5 | olafsvik
# Processing Record 43 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 5 | marataizes
# Processing Record 45 of Set 5 | hilo
# Processing Record 46 of Set 5 | mangan
# Processing Record 47 of Set 5 | igarka
# Processing Record 48 of Set 5 | provideniya
# Processing Record 49 of Set 5 | cidreira
# Processing Record 50 of Set 5 | taoudenni
# Processing Record 1 of Set 6 | champerico
# Processing Record 2 of Set 6 | evensk
# Processing Record 3 of Set 6 | mandera
# Processing Record 4 of Set 6 | imeni poliny osipenko
# Processing Record 5 of Set 6 | ardahan
# Processing Record 6 of Set 6 | khatanga
# Processing Record 7 of Set 6 | san jeronimo
# Processing Record 8 of Set 6 | lata
# Processing Record 9 of Set 6 | berlevag
# Processing Record 10 of Set 6 | hays
# Processing Record 11 of Set 6 | stornoway
# Processing Record 12 of Set 6 | mackay
# Processing Record 13 of Set 6 | dunedin
# Processing Record 14 of Set 6 | nouadhibou
# Processing Record 15 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 6 | nador
# Processing Record 17 of Set 6 | jacareacanga
# Processing Record 18 of Set 6 | amahai
# Processing Record 19 of Set 6 | mahabad
# Processing Record 20 of Set 6 | matagami
# Processing Record 21 of Set 6 | grindavik
# Processing Record 22 of Set 6 | tamandare
# Processing Record 23 of Set 6 | nanlong
# Processing Record 24 of Set 6 | viedma
# Processing Record 25 of Set 6 | deputatskiy
# Processing Record 26 of Set 6 | araouane
# Processing Record 27 of Set 6 | minot
# Processing Record 28 of Set 6 | natal
# Processing Record 29 of Set 6 | hualmay
# Processing Record 30 of Set 6 | madhupur
# Processing Record 31 of Set 6 | haapiti
# Processing Record 32 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 34 of Set 6 | the valley
# Processing Record 35 of Set 6 | campoverde
# Processing Record 36 of Set 6 | hambantota
# Processing Record 37 of Set 6 | phalaborwa
# Processing Record 38 of Set 6 | tarakan
# Processing Record 39 of Set 6 | bhindar
# Processing Record 40 of Set 6 | panacan
# Processing Record 41 of Set 6 | trelew
# Processing Record 42 of Set 6 | laviana
# Processing Record 43 of Set 6 | aykhal
# Processing Record 44 of Set 6 | sakakah
# Processing Record 45 of Set 6 | cherskiy
# Processing Record 46 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 6 | tweed
# Processing Record 48 of Set 6 | katobu
# Processing Record 49 of Set 6 | yulara
# Processing Record 50 of Set 6 | broome
# Processing Record 1 of Set 7 | andenes
# Processing Record 2 of Set 7 | taltal
# Processing Record 3 of Set 7 | desaguadero
# Processing Record 4 of Set 7 | tessalit
# Processing Record 5 of Set 7 | marsh harbour
# Processing Record 6 of Set 7 | katsuura
# Processing Record 7 of Set 7 | johnson city
# Processing Record 8 of Set 7 | luba
# Processing Record 9 of Set 7 | sioux lookout
# Processing Record 10 of Set 7 | oranjemund
# Processing Record 11 of Set 7 | simbahan
# Processing Record 12 of Set 7 | rocha
# Processing Record 13 of Set 7 | juegang
# Processing Record 14 of Set 7 | teguise
# Processing Record 15 of Set 7 | clyde river
# Processing Record 16 of Set 7 | olga
# Processing Record 17 of Set 7 | souillac
# Processing Record 18 of Set 7 | san cristobal
# Processing Record 19 of Set 7 | axim
# Processing Record 20 of Set 7 | sao filipe
# Processing Record 21 of Set 7 | udachnyy
# Processing Record 22 of Set 7 | strezhevoy
# Processing Record 23 of Set 7 | litoral del san juan
# City not found. Skipping...
# Processing Record 24 of Set 7 | paragominas
# Processing Record 25 of Set 7 | cosmopolis
# Processing Record 26 of Set 7 | zelenoborskiy
# Processing Record 27 of Set 7 | luderitz
# Processing Record 28 of Set 7 | vila velha
# Processing Record 29 of Set 7 | iberia
# Processing Record 30 of Set 7 | bereda
# Processing Record 31 of Set 7 | inirida
# Processing Record 32 of Set 7 | luwuk
# Processing Record 33 of Set 7 | izhma
# Processing Record 34 of Set 7 | sofiysk
# City not found. Skipping...
# Processing Record 35 of Set 7 | sarhari
# Processing Record 36 of Set 7 | boende
# Processing Record 37 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 7 | zhuhai
# Processing Record 39 of Set 7 | kahului
# Processing Record 40 of Set 7 | longyearbyen
# Processing Record 41 of Set 7 | gigmoto
# Processing Record 42 of Set 7 | krasnoselkup
# Processing Record 43 of Set 7 | piacabucu
# Processing Record 44 of Set 7 | lasa
# Processing Record 45 of Set 7 | labuan
# Processing Record 46 of Set 7 | kawalu
# Processing Record 47 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 7 | perrenjas
# City not found. Skipping...
# Processing Record 49 of Set 7 | richards bay
# Processing Record 50 of Set 7 | presidente epitacio
# Processing Record 1 of Set 8 | nishihara
# Processing Record 2 of Set 8 | acarau
# Processing Record 3 of Set 8 | kaeo
# Processing Record 4 of Set 8 | uribia
# Processing Record 5 of Set 8 | tabarqah
# City not found. Skipping...
# Processing Record 6 of Set 8 | great bend
# Processing Record 7 of Set 8 | chifeng
# Processing Record 8 of Set 8 | shache
# Processing Record 9 of Set 8 | gondar
# Processing Record 10 of Set 8 | high level
# Processing Record 11 of Set 8 | caracuaro
# Processing Record 12 of Set 8 | villa rica
# Processing Record 13 of Set 8 | cockburn town
# Processing Record 14 of Set 8 | manono
# Processing Record 15 of Set 8 | trinidad
# Processing Record 16 of Set 8 | laguna
# Processing Record 17 of Set 8 | rodrigues alves
# Processing Record 18 of Set 8 | ilulissat
# Processing Record 19 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 20 of Set 8 | shingu
# Processing Record 21 of Set 8 | coquimbo
# Processing Record 22 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 23 of Set 8 | shaghat
# Processing Record 24 of Set 8 | lincoln
# Processing Record 25 of Set 8 | bathsheba
# Processing Record 26 of Set 8 | kyaikkami
# Processing Record 27 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 8 | flinders
# Processing Record 29 of Set 8 | abu samrah
# Processing Record 30 of Set 8 | port lincoln
# Processing Record 31 of Set 8 | dolores
# Processing Record 32 of Set 8 | palmer
# Processing Record 33 of Set 8 | bayshore gardens
# Processing Record 34 of Set 8 | bowmore
# Processing Record 35 of Set 8 | brabova
# Processing Record 36 of Set 8 | stephenville
# Processing Record 37 of Set 8 | laje
# Processing Record 38 of Set 8 | guaratinga
# Processing Record 39 of Set 8 | guarumal
# Processing Record 40 of Set 8 | agbor
# Processing Record 41 of Set 8 | peniche
# Processing Record 42 of Set 8 | oistins
# Processing Record 43 of Set 8 | high prairie
# Processing Record 44 of Set 8 | maniitsoq
# Processing Record 45 of Set 8 | we
# City not found. Skipping...
# Processing Record 46 of Set 8 | aripuana
# Processing Record 47 of Set 8 | kieta
# Processing Record 48 of Set 8 | brae
# Processing Record 49 of Set 8 | dinsor
# City not found. Skipping...
# Processing Record 50 of Set 8 | ipswich
# Processing Record 1 of Set 9 | duku
# Processing Record 2 of Set 9 | henties bay
# Processing Record 3 of Set 9 | catamarca
# Processing Record 4 of Set 9 | calabozo
# Processing Record 5 of Set 9 | kismayo
# Processing Record 6 of Set 9 | ler
# Processing Record 7 of Set 9 | sumen
# City not found. Skipping...
# Processing Record 8 of Set 9 | fairbanks
# Processing Record 9 of Set 9 | erenhot
# Processing Record 10 of Set 9 | hamburg
# Processing Record 11 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 9 | port macquarie
# Processing Record 13 of Set 9 | khanu woralaksaburi
# Processing Record 14 of Set 9 | mustang
# Processing Record 15 of Set 9 | chara
# Processing Record 16 of Set 9 | pisco
# Processing Record 17 of Set 9 | vangaindrano
# Processing Record 18 of Set 9 | faya
# Processing Record 19 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 20 of Set 9 | san patricio
# Processing Record 21 of Set 9 | panaba
# Processing Record 22 of Set 9 | merauke
# Processing Record 23 of Set 9 | sylva
# Processing Record 24 of Set 9 | alexandria
# Processing Record 25 of Set 9 | carroll
# Processing Record 26 of Set 9 | tynset
# Processing Record 27 of Set 9 | buy
# Processing Record 28 of Set 9 | vardo
# Processing Record 29 of Set 9 | manjeri
# Processing Record 30 of Set 9 | batticaloa
# Processing Record 31 of Set 9 | sayyan
# Processing Record 32 of Set 9 | ormara
# Processing Record 33 of Set 9 | denpasar
# Processing Record 34 of Set 9 | yumen
# Processing Record 35 of Set 9 | cairns
# Processing Record 36 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 9 | noboribetsu
# Processing Record 38 of Set 9 | knokke-heist
# Processing Record 39 of Set 9 | talnakh
# Processing Record 40 of Set 9 | caraballeda
# Processing Record 41 of Set 9 | kijang
# Processing Record 42 of Set 9 | georgetown
# Processing Record 43 of Set 9 | prince rupert
# Processing Record 44 of Set 9 | kedrovyy
# Processing Record 45 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 46 of Set 9 | panjab
# Processing Record 47 of Set 9 | antofagasta
# Processing Record 48 of Set 9 | saint-ambroise
# Processing Record 49 of Set 9 | kamaishi
# Processing Record 50 of Set 9 | antalaha
# Processing Record 1 of Set 10 | gainesville
# Processing Record 2 of Set 10 | beidao
# Processing Record 3 of Set 10 | jumla
# Processing Record 4 of Set 10 | palora
# Processing Record 5 of Set 10 | camopi
# Processing Record 6 of Set 10 | gambela
# Processing Record 7 of Set 10 | gamba
# Processing Record 8 of Set 10 | leshukonskoye
# Processing Record 9 of Set 10 | kruisfontein
# Processing Record 10 of Set 10 | kamennomostskoye
# Processing Record 11 of Set 10 | mweka
# Processing Record 12 of Set 10 | beringovskiy
# Processing Record 13 of Set 10 | waipawa
# Processing Record 14 of Set 10 | mpanda
# Processing Record 15 of Set 10 | sola
# Processing Record 16 of Set 10 | saint george
# Processing Record 17 of Set 10 | sun valley
# Processing Record 18 of Set 10 | general macarthur
# Processing Record 19 of Set 10 | kadur
# Processing Record 20 of Set 10 | kemin
# Processing Record 21 of Set 10 | vila franca do campo
# Processing Record 22 of Set 10 | atar
# Processing Record 23 of Set 10 | ibra
# Processing Record 24 of Set 10 | asmar
# Processing Record 25 of Set 10 | xitla
# City not found. Skipping...
# Processing Record 26 of Set 10 | cururupu
# Processing Record 27 of Set 10 | vila
# Processing Record 28 of Set 10 | nakhon si thammarat
# Processing Record 29 of Set 10 | ossora
# Processing Record 30 of Set 10 | oussouye
# Processing Record 31 of Set 10 | wukari
# Processing Record 32 of Set 10 | novaya igirma
# Processing Record 33 of Set 10 | comodoro rivadavia
# Processing Record 34 of Set 10 | imeni zhelyabova
# Processing Record 35 of Set 10 | samarkand
# Processing Record 36 of Set 10 | mnogovershinnyy
# Processing Record 37 of Set 10 | kavaratti
# Processing Record 38 of Set 10 | handan
# Processing Record 39 of Set 10 | stokmarknes
# Processing Record 40 of Set 10 | knysna
# Processing Record 41 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 10 | jashpurnagar
# Processing Record 43 of Set 10 | chapais
# Processing Record 44 of Set 10 | monroe
# Processing Record 45 of Set 10 | hasaki
# Processing Record 46 of Set 10 | turukhansk
# Processing Record 47 of Set 10 | talavera
# Processing Record 48 of Set 10 | yakeshi
# Processing Record 49 of Set 10 | marsa matruh
# Processing Record 50 of Set 10 | baruun-urt
# Processing Record 1 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 2 of Set 11 | fredericton
# Processing Record 3 of Set 11 | kaseda
# Processing Record 4 of Set 11 | ashdod
# Processing Record 5 of Set 11 | churapcha
# Processing Record 6 of Set 11 | porto novo
# Processing Record 7 of Set 11 | stykkisholmur
# Processing Record 8 of Set 11 | pleasanton
# Processing Record 9 of Set 11 | kununurra
# Processing Record 10 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 11 | komsomolskiy
# Processing Record 12 of Set 11 | misratah
# Processing Record 13 of Set 11 | novyy svit
# Processing Record 14 of Set 11 | omsk
# Processing Record 15 of Set 11 | hohhot
# Processing Record 16 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 11 | botwood
# Processing Record 18 of Set 11 | emerald
# Processing Record 19 of Set 11 | mount gambier
# Processing Record 20 of Set 11 | huarmey
# Processing Record 21 of Set 11 | chumikan
# Processing Record 22 of Set 11 | martapura
# Processing Record 23 of Set 11 | abnub
# Processing Record 24 of Set 11 | rundu
# Processing Record 25 of Set 11 | vostok
# Processing Record 26 of Set 11 | maine-soroa
# Processing Record 27 of Set 11 | hovd
# Processing Record 28 of Set 11 | college
# Processing Record 29 of Set 11 | liwonde
# Processing Record 30 of Set 11 | kulu
# Processing Record 31 of Set 11 | novosysoyevka
# Processing Record 32 of Set 11 | aquidauana
# Processing Record 33 of Set 11 | morgan city
# Processing Record 34 of Set 11 | snezhnogorsk
# Processing Record 35 of Set 11 | sur
# Processing Record 36 of Set 11 | olinda
# Processing Record 37 of Set 11 | ahipara
# Processing Record 38 of Set 11 | nynashamn
# Processing Record 39 of Set 11 | bandarbeyla
# Processing Record 40 of Set 11 | mirnyy
# Processing Record 41 of Set 11 | raga
# Processing Record 42 of Set 11 | lavrentiya
# Processing Record 43 of Set 11 | zambezi
# Processing Record 44 of Set 11 | constitucion
# Processing Record 45 of Set 11 | igurusi
# Processing Record 46 of Set 11 | hami
# Processing Record 47 of Set 11 | anaconda
# Processing Record 48 of Set 11 | warud
# Processing Record 49 of Set 11 | payo
# Processing Record 50 of Set 11 | bud
# Processing Record 1 of Set 12 | thunder bay
# Processing Record 2 of Set 12 | yatou
# Processing Record 3 of Set 12 | racine
# Processing Record 4 of Set 12 | paracuru
# Processing Record 5 of Set 12 | kimberley
# Processing Record 6 of Set 12 | yefimovskiy
# City not found. Skipping...
# Processing Record 7 of Set 12 | meulaboh
# Processing Record 8 of Set 12 | lyuban
# Processing Record 9 of Set 12 | malakal
# Processing Record 10 of Set 12 | dalbandin
# Processing Record 11 of Set 12 | bugko
# Processing Record 12 of Set 12 | kulhudhuffushi
# Processing Record 13 of Set 12 | abay
# Processing Record 14 of Set 12 | sidney
# Processing Record 15 of Set 12 | sarangani
# Processing Record 16 of Set 12 | puerto escondido
# Processing Record 17 of Set 12 | hazorasp
# Processing Record 18 of Set 12 | hamilton
# Processing Record 19 of Set 12 | gabuyan
# Processing Record 20 of Set 12 | novominskaya
# Processing Record 21 of Set 12 | srednekolymsk
# Processing Record 22 of Set 12 | tommot
# Processing Record 23 of Set 12 | masvingo
# Processing Record 24 of Set 12 | price
# Processing Record 25 of Set 12 | sharan
# Processing Record 26 of Set 12 | schweinfurt
# Processing Record 27 of Set 12 | linchuan
# City not found. Skipping...
# Processing Record 28 of Set 12 | kanturk
# Processing Record 29 of Set 12 | moosomin
# Processing Record 30 of Set 12 | mbeya
# Processing Record 31 of Set 12 | imbituba
# Processing Record 32 of Set 12 | trairi
# Processing Record 33 of Set 12 | namibe
# Processing Record 34 of Set 12 | borovskoy
# Processing Record 35 of Set 12 | fairview
# Processing Record 36 of Set 12 | fort frances
# Processing Record 37 of Set 12 | chau doc
# Processing Record 38 of Set 12 | mozarlandia
# Processing Record 39 of Set 12 | geraldton
# Processing Record 40 of Set 12 | ati
# Processing Record 41 of Set 12 | springs
# Processing Record 42 of Set 12 | lagos
# Processing Record 43 of Set 12 | uelzen
# Processing Record 44 of Set 12 | santa fe
# Processing Record 45 of Set 12 | hofn
# Processing Record 46 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 12 | carutapera
# Processing Record 48 of Set 12 | inhambane
# Processing Record 49 of Set 12 | charters towers
# Processing Record 50 of Set 12 | nikel
# Processing Record 1 of Set 13 | midland
# Processing Record 2 of Set 13 | laguna de perlas
# Processing Record 3 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 13 | kasangulu
# Processing Record 5 of Set 13 | morant bay
# Processing Record 6 of Set 13 | hadejia
# Processing Record 7 of Set 13 | ginda
# Processing Record 8 of Set 13 | mardin
# Processing Record 9 of Set 13 | osorno
# Processing Record 10 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 13 | pacific grove
# Processing Record 12 of Set 13 | buncrana
# Processing Record 13 of Set 13 | narasapur
# Processing Record 14 of Set 13 | miles city
# Processing Record 15 of Set 13 | herat
# Processing Record 16 of Set 13 | umm kaddadah
# Processing Record 17 of Set 13 | leh
# Processing Record 18 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 19 of Set 13 | ilebo
# Processing Record 20 of Set 13 | abalak
# Processing Record 21 of Set 13 | contamana
# Processing Record 22 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 23 of Set 13 | bilibino
# Processing Record 24 of Set 13 | asmara
# Processing Record 25 of Set 13 | sibenik
# Processing Record 26 of Set 13 | boa vista
# Processing Record 27 of Set 13 | boisoara
# Processing Record 28 of Set 13 | manokwari
# Processing Record 29 of Set 13 | king city
# Processing Record 30 of Set 13 | khokhlovo
# Processing Record 31 of Set 13 | altay
# Processing Record 32 of Set 13 | mazamari
# Processing Record 33 of Set 13 | isshiki
# City not found. Skipping...
# Processing Record 34 of Set 13 | shimoda
# Processing Record 35 of Set 13 | nanakuli
# Processing Record 36 of Set 13 | vung tau
# Processing Record 37 of Set 13 | sinjar
# Processing Record 38 of Set 13 | pringsewu
# Processing Record 39 of Set 13 | beira
# Processing Record 40 of Set 13 | saint-leu
# Processing Record 41 of Set 13 | saurimo
# Processing Record 42 of Set 13 | portland
# Processing Record 43 of Set 13 | shizunai
# Processing Record 44 of Set 13 | oakdale
# Processing Record 45 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 46 of Set 13 | yerbogachen
# Processing Record 47 of Set 13 | pittsfield
# Processing Record 48 of Set 13 | urumqi
# Processing Record 49 of Set 13 | port hardy
# Processing Record 50 of Set 13 | piney green
# Processing Record 1 of Set 14 | candido de abreu
# Processing Record 2 of Set 14 | devonport
# Processing Record 3 of Set 14 | matay
# Processing Record 4 of Set 14 | chicama
# Processing Record 5 of Set 14 | salalah
# Processing Record 6 of Set 14 | boiro
# Processing Record 7 of Set 14 | kasongo-lunda
# Processing Record 8 of Set 14 | binzhou
# Processing Record 9 of Set 14 | meadow lake
# Processing Record 10 of Set 14 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 11 of Set 14 | sao felix do xingu
# Processing Record 12 of Set 14 | kostomuksha
# Processing Record 13 of Set 14 | palestine
# Processing Record 14 of Set 14 | hammerfest
# Processing Record 15 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 16 of Set 14 | katihar
# Processing Record 17 of Set 14 | kamyshla
# Processing Record 18 of Set 14 | zhireken
# Processing Record 19 of Set 14 | effingham
# Processing Record 20 of Set 14 | batagay
# Processing Record 21 of Set 14 | goderich
# Processing Record 22 of Set 14 | sabang
# Processing Record 23 of Set 14 | north bend
# Processing Record 24 of Set 14 | vilhena
# Processing Record 25 of Set 14 | weinan
# Processing Record 26 of Set 14 | eslov
# Processing Record 27 of Set 14 | sharjah
# Processing Record 28 of Set 14 | passo de camaragibe
# Processing Record 29 of Set 14 | nioro
# Processing Record 30 of Set 14 | karakol
# Processing Record 31 of Set 14 | narsaq
# Processing Record 32 of Set 14 | horbranz
# Processing Record 33 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 34 of Set 14 | maragogi
# Processing Record 35 of Set 14 | salinas
# Processing Record 36 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 37 of Set 14 | santa cruz de la palma
# Processing Record 38 of Set 14 | baykit
# Processing Record 39 of Set 14 | lianzhou
# Processing Record 40 of Set 14 | tyukalinsk
# Processing Record 41 of Set 14 | le port
# Processing Record 42 of Set 14 | caravelas
# Processing Record 43 of Set 14 | vestmanna
# Processing Record 44 of Set 14 | meiktila
# Processing Record 45 of Set 14 | ouadda
# Processing Record 46 of Set 14 | itoman
# Processing Record 47 of Set 14 | kakching
# Processing Record 48 of Set 14 | akranes
# Processing Record 49 of Set 14 | marzuq
# Processing Record 50 of Set 14 | robertsport
# Processing Record 1 of Set 15 | nikolayevskaya
# Processing Record 2 of Set 15 | ituni
# City not found. Skipping...
# Processing Record 3 of Set 15 | sotnikovo
# Processing Record 4 of Set 15 | ust-kut
# Processing Record 5 of Set 15 | tuban
# Processing Record 6 of Set 15 | yar-sale
# Processing Record 7 of Set 15 | linjiang
# Processing Record 8 of Set 15 | ribeirao branco
# Processing Record 9 of Set 15 | kupang
# Processing Record 10 of Set 15 | kokkola
# Processing Record 11 of Set 15 | haines junction
# Processing Record 12 of Set 15 | alihe
# Processing Record 13 of Set 15 | roebourne
# Processing Record 14 of Set 15 | dingle
# Processing Record 15 of Set 15 | dunmore east
# Processing Record 16 of Set 15 | konya
# Processing Record 17 of Set 15 | kachiry
# Processing Record 18 of Set 15 | wajima
# Processing Record 19 of Set 15 | saint-raymond
# Processing Record 20 of Set 15 | rafai
# Processing Record 21 of Set 15 | ambilobe
# Processing Record 22 of Set 15 | baisha
# Processing Record 23 of Set 15 | terra santa
# Processing Record 24 of Set 15 | conde
# Processing Record 25 of Set 15 | casper
# Processing Record 26 of Set 15 | kushima
# Processing Record 27 of Set 15 | vilyuysk
# Processing Record 28 of Set 15 | dong xoai
# Processing Record 29 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 30 of Set 15 | campbell river
# Processing Record 31 of Set 15 | saint-louis
# Processing Record 32 of Set 15 | paris
# Processing Record 33 of Set 15 | sao gabriel da cachoeira
# Processing Record 34 of Set 15 | wucheng
# Processing Record 35 of Set 15 | lugazi
# Processing Record 36 of Set 15 | dombarovskiy
# Processing Record 37 of Set 15 | surgut
# Processing Record 38 of Set 15 | vieste
# Processing Record 39 of Set 15 | coahuayana
# Processing Record 40 of Set 15 | zapolyarnyy
# Processing Record 41 of Set 15 | cartagena
# Processing Record 42 of Set 15 | yelizovo
# Processing Record 43 of Set 15 | ujjain
# Processing Record 44 of Set 15 | egvekinot
# Processing Record 45 of Set 15 | macusani
# Processing Record 46 of Set 15 | shkotovo-26
# City not found. Skipping...
# Processing Record 47 of Set 15 | santo estevao
# Processing Record 48 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 15 | coihaique
# Processing Record 50 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 1 of Set 16 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 16 | sunrise manor
# Processing Record 3 of Set 16 | husavik
# Processing Record 4 of Set 16 | deyang
# Processing Record 5 of Set 16 | jalu
# Processing Record 6 of Set 16 | bon accord
# Processing Record 7 of Set 16 | kamenka
# Processing Record 8 of Set 16 | chino valley
# Processing Record 9 of Set 16 | ambo
# Processing Record 10 of Set 16 | terrace bay
# Processing Record 11 of Set 16 | sheridan
# Processing Record 12 of Set 16 | ahuimanu
# Processing Record 13 of Set 16 | gushi
# Processing Record 14 of Set 16 | ketchikan
# Processing Record 15 of Set 16 | irbil
# Processing Record 16 of Set 16 | vanderhoof
# Processing Record 17 of Set 16 | ilula
# Processing Record 18 of Set 16 | mehamn
# Processing Record 19 of Set 16 | osijek
# Processing Record 20 of Set 16 | west bay
# Processing Record 21 of Set 16 | la ronge
# Processing Record 22 of Set 16 | kuala terengganu
# Processing Record 23 of Set 16 | veere
# Processing Record 24 of Set 16 | roblin
# Processing Record 25 of Set 16 | san felipe
# Processing Record 26 of Set 16 | hervey bay
# Processing Record 27 of Set 16 | ust-tsilma
# Processing Record 28 of Set 16 | providencia
# Processing Record 29 of Set 16 | petropavlovsk-kamchatskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Nikolskoye  59.70   30.79     62.01        87          20
# 1             Barrow  71.29 -156.79     42.80        81          90
# 2         Masallatah  32.62   14.00     76.73        84          60
# 3              Lodja  -3.48   23.43     69.76        91         100
# 4  Sao Joao Da Barra -21.64  -41.05     64.89        72           3
# 5            Qaanaaq  77.48  -69.36     36.50        88         100
# 6      Ponta Delgada  37.73  -25.67     71.60        88          20
# 7         Drumheller  51.46 -112.71     78.01        36          61
# 8             Albany  42.60  -73.97     71.01        91          23
# 9            Bubaque  11.28  -15.83     80.71        82          98
#
#    Wind Speed Country      Description                 Date
# 0        4.47      RU       few clouds  2020-08-23 23:45:12
# 1        9.17      US  overcast clouds  2020-08-23 23:45:12
# 2       11.30      LY    broken clouds  2020-08-23 23:45:12
# 3        2.59      CD  overcast clouds  2020-08-23 23:41:08
# 4       11.61      BR        clear sky  2020-08-23 23:45:13
# 5        2.93      GL       light rain  2020-08-23 23:45:13
# 6        4.70      PT       few clouds  2020-08-23 23:44:59
# 7        6.51      CA    broken clouds  2020-08-23 23:42:58
# 8        3.36      US       light rain  2020-08-23 23:45:01
# 9       10.18      GW  overcast clouds  2020-08-23 23:45:13

# %%
#re-ordering the columns to improve readability
New_Column_Order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[New_Column_Order]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_df
# Out:
#                           City Country    Lat     Lng  Max Temp  Humidity  \
# 0                   Nikolskoye      RU  59.70   30.79     62.01        87
# 1                       Barrow      US  71.29 -156.79     42.80        81
# 2                   Masallatah      LY  32.62   14.00     76.73        84
# 3                        Lodja      CD  -3.48   23.43     69.76        91
# 4            Sao Joao Da Barra      BR -21.64  -41.05     64.89        72
# ..                         ...     ...    ...     ...       ...       ...
# 715                 San Felipe      VE  10.34  -68.74     74.66        88
# 716                 Hervey Bay      AU -25.30  152.85     60.80        29
# 717                 Ust-Tsilma      RU  65.44   52.15     55.18        94
# 718                Providencia      MX  28.72 -111.58    105.01        37
# 719  Petropavlovsk-Kamchatskiy      RU  53.05  158.65     57.20        93
#
#      Cloudiness  Wind Speed       Description
# 0            20        4.47        few clouds
# 1            90        9.17   overcast clouds
# 2            60       11.30     broken clouds
# 3           100        2.59   overcast clouds
# 4             3       11.61         clear sky
# ..          ...         ...               ...
# 715          55        2.08     broken clouds
# 716           0        9.17         clear sky
# 717          83        4.36     broken clouds
# 718          21       17.00        few clouds
# 719          40        6.71  scattered clouds
#
# [720 rows x 9 columns]
