# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import requests

# %%
from citipy import citipy

# %%
from datetime import datetime

# %%
# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=37cdbe8ee84d2e90132ae5124aaf9491

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 722

# %%
city_url = url + "&q=" + "Boston"
city_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=37cdbe8ee84d2e90132ae5124aaf9491&q=Boston'

# %%
city_weather
# Out:
# {'coord': {'lon': 16.85, 'lat': 41.12},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 75.74,
#   'feels_like': 82.49,
#   'temp_min': 73.99,
#   'temp_max': 77,
#   'pressure': 1010,
#   'humidity': 88},
#  'visibility': 10000,
#  'wind': {'speed': 3.36, 'deg': 30},
#  'clouds': {'all': 1},
#  'dt': 1598225149,
#  'sys': {'type': 1,
#   'id': 6680,
#   'country': 'IT',
#   'sunrise': 1598242296,
#   'sunset': 1598290716},
#  'timezone': 7200,
#  'id': 6542001,
#  'name': 'Bari',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description,
                          "Date": city_date})
        
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | araouane
# Processing Record 2 of Set 1 | rio grande
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | carnarvon
# Processing Record 5 of Set 1 | tiksi
# Processing Record 6 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | pisco
# Processing Record 12 of Set 1 | laguna
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | bela cruz
# Processing Record 17 of Set 1 | saba
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 1 | shchelyayur
# City not found. Skipping...
# Processing Record 21 of Set 1 | saldanha
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | udachnyy
# Processing Record 26 of Set 1 | bengkulu
# Processing Record 27 of Set 1 | geraldton
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | chuy
# Processing Record 31 of Set 1 | cidreira
# Processing Record 32 of Set 1 | bako
# Processing Record 33 of Set 1 | sinnamary
# Processing Record 34 of Set 1 | auki
# Processing Record 35 of Set 1 | marathon
# Processing Record 36 of Set 1 | marsa matruh
# Processing Record 37 of Set 1 | fairbanks
# Processing Record 38 of Set 1 | saskylakh
# Processing Record 39 of Set 1 | xuddur
# Processing Record 40 of Set 1 | ponta do sol
# Processing Record 41 of Set 1 | madera
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | mitsamiouli
# Processing Record 44 of Set 1 | inongo
# Processing Record 45 of Set 1 | los llanos de aridane
# Processing Record 46 of Set 1 | charleston
# Processing Record 47 of Set 1 | te anau
# Processing Record 48 of Set 1 | maldonado
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | antofagasta
# Processing Record 1 of Set 2 | ulaangom
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | clyde river
# Processing Record 4 of Set 2 | qaanaaq
# Processing Record 5 of Set 2 | linjiang
# Processing Record 6 of Set 2 | klaksvik
# Processing Record 7 of Set 2 | albany
# Processing Record 8 of Set 2 | yulara
# Processing Record 9 of Set 2 | sioux lookout
# Processing Record 10 of Set 2 | vanavara
# Processing Record 11 of Set 2 | port macquarie
# Processing Record 12 of Set 2 | punta arenas
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 2 | butaritari
# Processing Record 16 of Set 2 | cap malheureux
# Processing Record 17 of Set 2 | parnaiba
# Processing Record 18 of Set 2 | vostok
# Processing Record 19 of Set 2 | shingu
# Processing Record 20 of Set 2 | meulaboh
# Processing Record 21 of Set 2 | lamar
# Processing Record 22 of Set 2 | castro
# Processing Record 23 of Set 2 | oranjestad
# Processing Record 24 of Set 2 | cape town
# Processing Record 25 of Set 2 | moron
# Processing Record 26 of Set 2 | bababe
# City not found. Skipping...
# Processing Record 27 of Set 2 | kloulklubed
# Processing Record 28 of Set 2 | leningradskiy
# Processing Record 29 of Set 2 | a coruna
# Processing Record 30 of Set 2 | lompoc
# Processing Record 31 of Set 2 | kirakira
# Processing Record 32 of Set 2 | karaidel
# Processing Record 33 of Set 2 | hasaki
# Processing Record 34 of Set 2 | chokurdakh
# Processing Record 35 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 2 | port lincoln
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | koslan
# Processing Record 39 of Set 2 | barrow
# Processing Record 40 of Set 2 | aksu
# Processing Record 41 of Set 2 | muzhi
# Processing Record 42 of Set 2 | kamenka
# Processing Record 43 of Set 2 | hithadhoo
# Processing Record 44 of Set 2 | saint-augustin
# Processing Record 45 of Set 2 | dikson
# Processing Record 46 of Set 2 | gryfice
# Processing Record 47 of Set 2 | la ronge
# Processing Record 48 of Set 2 | palasa
# Processing Record 49 of Set 2 | buinsk
# Processing Record 50 of Set 2 | sug-aksy
# City not found. Skipping...
# Processing Record 1 of Set 3 | saint george
# Processing Record 2 of Set 3 | jamestown
# Processing Record 3 of Set 3 | kieta
# Processing Record 4 of Set 3 | mackay
# Processing Record 5 of Set 3 | longyearbyen
# Processing Record 6 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 3 | bhagwantnagar
# Processing Record 8 of Set 3 | svetlyy
# Processing Record 9 of Set 3 | alice
# Processing Record 10 of Set 3 | morondava
# Processing Record 11 of Set 3 | mahebourg
# Processing Record 12 of Set 3 | taganak
# Processing Record 13 of Set 3 | portland
# Processing Record 14 of Set 3 | mayumba
# Processing Record 15 of Set 3 | itarema
# Processing Record 16 of Set 3 | tharad
# Processing Record 17 of Set 3 | fort nelson
# Processing Record 18 of Set 3 | georgetown
# Processing Record 19 of Set 3 | torbay
# Processing Record 20 of Set 3 | high level
# Processing Record 21 of Set 3 | phetchaburi
# Processing Record 22 of Set 3 | labuan
# Processing Record 23 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 3 | havelock
# Processing Record 25 of Set 3 | padang
# Processing Record 26 of Set 3 | gigmoto
# Processing Record 27 of Set 3 | zyryanka
# Processing Record 28 of Set 3 | kholtoson
# Processing Record 29 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 3 | tautira
# Processing Record 31 of Set 3 | synya
# Processing Record 32 of Set 3 | port elizabeth
# Processing Record 33 of Set 3 | kaitangata
# Processing Record 34 of Set 3 | byron bay
# Processing Record 35 of Set 3 | san cristobal
# Processing Record 36 of Set 3 | protivin
# Processing Record 37 of Set 3 | onguday
# Processing Record 38 of Set 3 | airai
# Processing Record 39 of Set 3 | victoria
# Processing Record 40 of Set 3 | zurrieq
# Processing Record 41 of Set 3 | sao filipe
# Processing Record 42 of Set 3 | cabo san lucas
# Processing Record 43 of Set 3 | la rioja
# Processing Record 44 of Set 3 | mar del plata
# Processing Record 45 of Set 3 | kysyl-syr
# Processing Record 46 of Set 3 | taoudenni
# Processing Record 47 of Set 3 | arraial do cabo
# Processing Record 48 of Set 3 | bokspits
# City not found. Skipping...
# Processing Record 49 of Set 3 | mananjary
# Processing Record 50 of Set 3 | san patricio
# Processing Record 1 of Set 4 | kodiak
# Processing Record 2 of Set 4 | ketchikan
# Processing Record 3 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 4 | vardo
# Processing Record 5 of Set 4 | hamilton
# Processing Record 6 of Set 4 | roma
# Processing Record 7 of Set 4 | mount gambier
# Processing Record 8 of Set 4 | deputatskiy
# Processing Record 9 of Set 4 | zmeinogorsk
# Processing Record 10 of Set 4 | tual
# Processing Record 11 of Set 4 | talnakh
# Processing Record 12 of Set 4 | aksarka
# Processing Record 13 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 14 of Set 4 | champerico
# Processing Record 15 of Set 4 | nikolskoye
# Processing Record 16 of Set 4 | pousat
# City not found. Skipping...
# Processing Record 17 of Set 4 | severo-kurilsk
# Processing Record 18 of Set 4 | erenhot
# Processing Record 19 of Set 4 | warrnambool
# Processing Record 20 of Set 4 | natal
# Processing Record 21 of Set 4 | aljezur
# Processing Record 22 of Set 4 | vila velha
# Processing Record 23 of Set 4 | luderitz
# Processing Record 24 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 4 | wajima
# Processing Record 26 of Set 4 | kuhdasht
# Processing Record 27 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 28 of Set 4 | vaini
# Processing Record 29 of Set 4 | faanui
# Processing Record 30 of Set 4 | sorada
# Processing Record 31 of Set 4 | gusau
# Processing Record 32 of Set 4 | nouakchott
# Processing Record 33 of Set 4 | zhigansk
# Processing Record 34 of Set 4 | touros
# Processing Record 35 of Set 4 | sahuaripa
# Processing Record 36 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 4 | kruisfontein
# Processing Record 38 of Set 4 | lalmohan
# Processing Record 39 of Set 4 | nuuk
# Processing Record 40 of Set 4 | usinsk
# Processing Record 41 of Set 4 | sorland
# Processing Record 42 of Set 4 | turinskaya sloboda
# Processing Record 43 of Set 4 | port hardy
# Processing Record 44 of Set 4 | harbour breton
# Processing Record 45 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 4 | esperance
# Processing Record 47 of Set 4 | nanortalik
# Processing Record 48 of Set 4 | ostrovnoy
# Processing Record 49 of Set 4 | batemans bay
# Processing Record 50 of Set 4 | pevek
# Processing Record 1 of Set 5 | norman wells
# Processing Record 2 of Set 5 | la asuncion
# Processing Record 3 of Set 5 | ilulissat
# Processing Record 4 of Set 5 | banagher
# Processing Record 5 of Set 5 | visnes
# Processing Record 6 of Set 5 | nyurba
# Processing Record 7 of Set 5 | girne
# Processing Record 8 of Set 5 | gongzhuling
# Processing Record 9 of Set 5 | areado
# Processing Record 10 of Set 5 | nouadhibou
# Processing Record 11 of Set 5 | nemuro
# Processing Record 12 of Set 5 | santa adelia
# Processing Record 13 of Set 5 | maragogi
# Processing Record 14 of Set 5 | port-cartier
# Processing Record 15 of Set 5 | ramhormoz
# Processing Record 16 of Set 5 | moerai
# Processing Record 17 of Set 5 | saint-philippe
# Processing Record 18 of Set 5 | katsuura
# Processing Record 19 of Set 5 | oum hadjer
# Processing Record 20 of Set 5 | alice springs
# Processing Record 21 of Set 5 | catanzaro
# Processing Record 22 of Set 5 | ironton
# Processing Record 23 of Set 5 | pacific grove
# Processing Record 24 of Set 5 | tasiilaq
# Processing Record 25 of Set 5 | giresun
# Processing Record 26 of Set 5 | mendi
# Processing Record 27 of Set 5 | karlstad
# Processing Record 28 of Set 5 | lieto
# Processing Record 29 of Set 5 | jibuti
# Processing Record 30 of Set 5 | provideniya
# Processing Record 31 of Set 5 | lagoa
# Processing Record 32 of Set 5 | sinjar
# Processing Record 33 of Set 5 | oistins
# Processing Record 34 of Set 5 | ambon
# Processing Record 35 of Set 5 | ust-ishim
# Processing Record 36 of Set 5 | tessalit
# Processing Record 37 of Set 5 | manjacaze
# Processing Record 38 of Set 5 | linhares
# Processing Record 39 of Set 5 | madang
# Processing Record 40 of Set 5 | tura
# Processing Record 41 of Set 5 | bathsheba
# Processing Record 42 of Set 5 | chernyshevskiy
# Processing Record 43 of Set 5 | birjand
# Processing Record 44 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 45 of Set 5 | olafsvik
# Processing Record 46 of Set 5 | northam
# Processing Record 47 of Set 5 | skibbereen
# Processing Record 48 of Set 5 | camana
# Processing Record 49 of Set 5 | ust-kuyga
# Processing Record 50 of Set 5 | khatanga
# Processing Record 1 of Set 6 | yuzhou
# Processing Record 2 of Set 6 | isugod
# Processing Record 3 of Set 6 | bonthe
# Processing Record 4 of Set 6 | nisia floresta
# Processing Record 5 of Set 6 | tocopilla
# Processing Record 6 of Set 6 | irbeyskoye
# Processing Record 7 of Set 6 | kharitonovo
# Processing Record 8 of Set 6 | black river
# Processing Record 9 of Set 6 | san esteban
# Processing Record 10 of Set 6 | noumea
# Processing Record 11 of Set 6 | roura
# Processing Record 12 of Set 6 | kavieng
# Processing Record 13 of Set 6 | namie
# Processing Record 14 of Set 6 | harper
# Processing Record 15 of Set 6 | east london
# Processing Record 16 of Set 6 | alta floresta
# Processing Record 17 of Set 6 | hofn
# Processing Record 18 of Set 6 | skowhegan
# Processing Record 19 of Set 6 | broken hill
# Processing Record 20 of Set 6 | gurupa
# Processing Record 21 of Set 6 | develi
# Processing Record 22 of Set 6 | paamiut
# Processing Record 23 of Set 6 | balsas
# Processing Record 24 of Set 6 | doka
# Processing Record 25 of Set 6 | beringovskiy
# Processing Record 26 of Set 6 | wolmaranstad
# City not found. Skipping...
# Processing Record 27 of Set 6 | nanguneri
# Processing Record 28 of Set 6 | zhuanghe
# Processing Record 29 of Set 6 | masallatah
# Processing Record 30 of Set 6 | riberalta
# Processing Record 31 of Set 6 | puerto narino
# Processing Record 32 of Set 6 | rosarito
# Processing Record 33 of Set 6 | rajnagar
# Processing Record 34 of Set 6 | monduli
# Processing Record 35 of Set 6 | gryazovets
# Processing Record 36 of Set 6 | karratha
# Processing Record 37 of Set 6 | ontario
# Processing Record 38 of Set 6 | cambridge
# Processing Record 39 of Set 6 | chuguyevka
# Processing Record 40 of Set 6 | asind
# Processing Record 41 of Set 6 | yar-sale
# Processing Record 42 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 6 | saurimo
# Processing Record 44 of Set 6 | upernavik
# Processing Record 45 of Set 6 | chumikan
# Processing Record 46 of Set 6 | salalah
# Processing Record 47 of Set 6 | palmer
# Processing Record 48 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 6 | praia
# Processing Record 50 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 7 | celestun
# Processing Record 2 of Set 7 | taman
# Processing Record 3 of Set 7 | akyab
# Processing Record 4 of Set 7 | duz
# City not found. Skipping...
# Processing Record 5 of Set 7 | bethel
# Processing Record 6 of Set 7 | comodoro rivadavia
# Processing Record 7 of Set 7 | kalmunai
# Processing Record 8 of Set 7 | ravar
# Processing Record 9 of Set 7 | ascension
# Processing Record 10 of Set 7 | umred
# Processing Record 11 of Set 7 | jurado
# Processing Record 12 of Set 7 | ornskoldsvik
# Processing Record 13 of Set 7 | jenbach
# Processing Record 14 of Set 7 | balkanabat
# Processing Record 15 of Set 7 | ancud
# Processing Record 16 of Set 7 | tupik
# Processing Record 17 of Set 7 | tuatapere
# Processing Record 18 of Set 7 | iqaluit
# Processing Record 19 of Set 7 | margate
# Processing Record 20 of Set 7 | najran
# Processing Record 21 of Set 7 | basti
# Processing Record 22 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 23 of Set 7 | marawi
# Processing Record 24 of Set 7 | scarborough
# Processing Record 25 of Set 7 | wynyard
# Processing Record 26 of Set 7 | lebu
# Processing Record 27 of Set 7 | sept-iles
# Processing Record 28 of Set 7 | aginskoye
# Processing Record 29 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 30 of Set 7 | bardiyah
# Processing Record 31 of Set 7 | bintulu
# Processing Record 32 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 7 | monteagudo
# Processing Record 34 of Set 7 | khash
# Processing Record 35 of Set 7 | ponta delgada
# Processing Record 36 of Set 7 | buala
# Processing Record 37 of Set 7 | bereda
# Processing Record 38 of Set 7 | aklavik
# Processing Record 39 of Set 7 | pareora
# Processing Record 40 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 7 | lewistown
# Processing Record 42 of Set 7 | nipawin
# Processing Record 43 of Set 7 | karatuzskoye
# Processing Record 44 of Set 7 | constitucion
# Processing Record 45 of Set 7 | raga
# Processing Record 46 of Set 7 | pangnirtung
# Processing Record 47 of Set 7 | komsomolskiy
# Processing Record 48 of Set 7 | olot
# Processing Record 49 of Set 7 | tabriz
# Processing Record 50 of Set 7 | goderich
# Processing Record 1 of Set 8 | gaogou
# Processing Record 2 of Set 8 | faya
# Processing Record 3 of Set 8 | falkenberg
# Processing Record 4 of Set 8 | solwezi
# Processing Record 5 of Set 8 | lata
# Processing Record 6 of Set 8 | brae
# Processing Record 7 of Set 8 | leh
# Processing Record 8 of Set 8 | poum
# Processing Record 9 of Set 8 | mana
# Processing Record 10 of Set 8 | coquimbo
# Processing Record 11 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 8 | sisimiut
# Processing Record 13 of Set 8 | asau
# Processing Record 14 of Set 8 | arvi
# Processing Record 15 of Set 8 | gonbad-e qabus
# Processing Record 16 of Set 8 | lukovetskiy
# Processing Record 17 of Set 8 | bambous virieux
# Processing Record 18 of Set 8 | cherskiy
# Processing Record 19 of Set 8 | abalak
# Processing Record 20 of Set 8 | wanning
# Processing Record 21 of Set 8 | potrerillos
# Processing Record 22 of Set 8 | bakel
# Processing Record 23 of Set 8 | puerto escondido
# Processing Record 24 of Set 8 | vila franca do campo
# Processing Record 25 of Set 8 | waddan
# Processing Record 26 of Set 8 | okha
# Processing Record 27 of Set 8 | kahului
# Processing Record 28 of Set 8 | coxim
# Processing Record 29 of Set 8 | thap khlo
# Processing Record 30 of Set 8 | atar
# Processing Record 31 of Set 8 | nioro
# Processing Record 32 of Set 8 | ca mau
# Processing Record 33 of Set 8 | tazovskiy
# Processing Record 34 of Set 8 | portage
# Processing Record 35 of Set 8 | pitimbu
# Processing Record 36 of Set 8 | fortuna
# Processing Record 37 of Set 8 | domna
# Processing Record 38 of Set 8 | saint anthony
# Processing Record 39 of Set 8 | atambua
# Processing Record 40 of Set 8 | turukhansk
# Processing Record 41 of Set 8 | victor harbor
# Processing Record 42 of Set 8 | vestmanna
# Processing Record 43 of Set 8 | kerrobert
# Processing Record 44 of Set 8 | cuamba
# Processing Record 45 of Set 8 | naples
# Processing Record 46 of Set 8 | kutum
# Processing Record 47 of Set 8 | gao
# Processing Record 48 of Set 8 | sakakah
# Processing Record 49 of Set 8 | kjollefjord
# Processing Record 50 of Set 8 | kurilsk
# Processing Record 1 of Set 9 | flinders
# Processing Record 2 of Set 9 | puerto lopez
# Processing Record 3 of Set 9 | ranong
# Processing Record 4 of Set 9 | ahipara
# Processing Record 5 of Set 9 | mizdah
# Processing Record 6 of Set 9 | broome
# Processing Record 7 of Set 9 | bang saphan
# Processing Record 8 of Set 9 | ouesso
# Processing Record 9 of Set 9 | da nang
# Processing Record 10 of Set 9 | sadowara
# City not found. Skipping...
# Processing Record 11 of Set 9 | san joaquin
# Processing Record 12 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 13 of Set 9 | avera
# Processing Record 14 of Set 9 | teya
# Processing Record 15 of Set 9 | narsaq
# Processing Record 16 of Set 9 | henties bay
# Processing Record 17 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 9 | lafia
# Processing Record 19 of Set 9 | dillon
# Processing Record 20 of Set 9 | pochutla
# Processing Record 21 of Set 9 | dzaoudzi
# Processing Record 22 of Set 9 | vasilsursk
# Processing Record 23 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 24 of Set 9 | spring hill
# Processing Record 25 of Set 9 | kitimat
# Processing Record 26 of Set 9 | diego de almagro
# Processing Record 27 of Set 9 | grindavik
# Processing Record 28 of Set 9 | sola
# Processing Record 29 of Set 9 | gogrial
# Processing Record 30 of Set 9 | port blair
# Processing Record 31 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 9 | tocache
# Processing Record 33 of Set 9 | palu
# Processing Record 34 of Set 9 | shiyan
# Processing Record 35 of Set 9 | tateyama
# Processing Record 36 of Set 9 | catalina
# Processing Record 37 of Set 9 | moulins
# Processing Record 38 of Set 9 | buraydah
# Processing Record 39 of Set 9 | guerrero negro
# Processing Record 40 of Set 9 | egvekinot
# Processing Record 41 of Set 9 | acapulco
# Processing Record 42 of Set 9 | acarau
# Processing Record 43 of Set 9 | sosnovo-ozerskoye
# Processing Record 44 of Set 9 | payyannur
# Processing Record 45 of Set 9 | lavrentiya
# Processing Record 46 of Set 9 | belaya gora
# Processing Record 47 of Set 9 | grimari
# City not found. Skipping...
# Processing Record 48 of Set 9 | sangin
# Processing Record 49 of Set 9 | pangody
# Processing Record 50 of Set 9 | krasnoselkup
# Processing Record 1 of Set 10 | zelenoborskiy
# Processing Record 2 of Set 10 | bani walid
# Processing Record 3 of Set 10 | kavaratti
# Processing Record 4 of Set 10 | berdigestyakh
# Processing Record 5 of Set 10 | saryozek
# Processing Record 6 of Set 10 | tigzirt
# Processing Record 7 of Set 10 | homer
# Processing Record 8 of Set 10 | richards bay
# Processing Record 9 of Set 10 | sur
# Processing Record 10 of Set 10 | nevel
# Processing Record 11 of Set 10 | isangel
# Processing Record 12 of Set 10 | taltal
# Processing Record 13 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 10 | beaufort
# Processing Record 15 of Set 10 | quatre cocos
# Processing Record 16 of Set 10 | husavik
# Processing Record 17 of Set 10 | wattegama
# Processing Record 18 of Set 10 | matara
# Processing Record 19 of Set 10 | faxinal
# Processing Record 20 of Set 10 | chapais
# Processing Record 21 of Set 10 | valdivia
# Processing Record 22 of Set 10 | fukue
# Processing Record 23 of Set 10 | awjilah
# Processing Record 24 of Set 10 | labuhan
# Processing Record 25 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 10 | grootfontein
# Processing Record 27 of Set 10 | balikpapan
# Processing Record 28 of Set 10 | zaraza
# Processing Record 29 of Set 10 | moussoro
# Processing Record 30 of Set 10 | sindor
# Processing Record 31 of Set 10 | port hedland
# Processing Record 32 of Set 10 | chaoyang
# Processing Record 33 of Set 10 | smolenka
# Processing Record 34 of Set 10 | souillac
# Processing Record 35 of Set 10 | altus
# Processing Record 36 of Set 10 | iberia
# Processing Record 37 of Set 10 | san juan
# Processing Record 38 of Set 10 | lorengau
# Processing Record 39 of Set 10 | odweyne
# Processing Record 40 of Set 10 | nhulunbuy
# Processing Record 41 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 10 | kupang
# Processing Record 43 of Set 10 | tamboril
# Processing Record 44 of Set 10 | maltahohe
# Processing Record 45 of Set 10 | shimoda
# Processing Record 46 of Set 10 | ilo
# Processing Record 47 of Set 10 | alyangula
# Processing Record 48 of Set 10 | kulhudhuffushi
# Processing Record 49 of Set 10 | huarmey
# Processing Record 50 of Set 10 | evanston
# Processing Record 1 of Set 11 | zhanaozen
# Processing Record 2 of Set 11 | grand gaube
# Processing Record 3 of Set 11 | gambela
# Processing Record 4 of Set 11 | shenjiamen
# Processing Record 5 of Set 11 | sitka
# Processing Record 6 of Set 11 | urumqi
# Processing Record 7 of Set 11 | abu jubayhah
# City not found. Skipping...
# Processing Record 8 of Set 11 | savannah bight
# Processing Record 9 of Set 11 | the valley
# Processing Record 10 of Set 11 | kununurra
# Processing Record 11 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 12 of Set 11 | hobyo
# Processing Record 13 of Set 11 | atbasar
# Processing Record 14 of Set 11 | talaya
# Processing Record 15 of Set 11 | minna
# Processing Record 16 of Set 11 | corinto
# Processing Record 17 of Set 11 | cockburn town
# Processing Record 18 of Set 11 | shushtar
# Processing Record 19 of Set 11 | hami
# Processing Record 20 of Set 11 | praya
# Processing Record 21 of Set 11 | bajil
# Processing Record 22 of Set 11 | dawlatabad
# Processing Record 23 of Set 11 | naze
# Processing Record 24 of Set 11 | dingle
# Processing Record 25 of Set 11 | kudahuvadhoo
# Processing Record 26 of Set 11 | palmas
# Processing Record 27 of Set 11 | wagar
# Processing Record 28 of Set 11 | bauchi
# Processing Record 29 of Set 11 | mogadishu
# Processing Record 30 of Set 11 | esil
# Processing Record 31 of Set 11 | iskateley
# Processing Record 32 of Set 11 | thompson
# Processing Record 33 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 34 of Set 11 | adrar
# Processing Record 35 of Set 11 | manzil jamil
# City not found. Skipping...
# Processing Record 36 of Set 11 | gien
# Processing Record 37 of Set 11 | notre-dame-du-lac
# Processing Record 38 of Set 11 | reconquista
# Processing Record 39 of Set 11 | sao joao de pirabas
# Processing Record 40 of Set 11 | north platte
# Processing Record 41 of Set 11 | launceston
# Processing Record 42 of Set 11 | griffith
# Processing Record 43 of Set 11 | alindao
# Processing Record 44 of Set 11 | lingao
# Processing Record 45 of Set 11 | vao
# Processing Record 46 of Set 11 | zhuhai
# Processing Record 47 of Set 11 | sierra vista
# Processing Record 48 of Set 11 | elat
# Processing Record 49 of Set 11 | plettenberg bay
# Processing Record 50 of Set 11 | qaqortoq
# Processing Record 1 of Set 12 | redcar
# Processing Record 2 of Set 12 | oussouye
# Processing Record 3 of Set 12 | codrington
# Processing Record 4 of Set 12 | shubarshi
# Processing Record 5 of Set 12 | ler
# Processing Record 6 of Set 12 | boyolangu
# Processing Record 7 of Set 12 | weymouth
# Processing Record 8 of Set 12 | vicksburg
# Processing Record 9 of Set 12 | malgrat de mar
# Processing Record 10 of Set 12 | lyman
# Processing Record 11 of Set 12 | christchurch
# Processing Record 12 of Set 12 | guiratinga
# Processing Record 13 of Set 12 | coahuayana
# Processing Record 14 of Set 12 | puerto colombia
# Processing Record 15 of Set 12 | namibe
# Processing Record 16 of Set 12 | kumylzhenskaya
# Processing Record 17 of Set 12 | metro
# Processing Record 18 of Set 12 | namatanai
# Processing Record 19 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 20 of Set 12 | roald
# Processing Record 21 of Set 12 | mahaicony
# City not found. Skipping...
# Processing Record 22 of Set 12 | bol
# Processing Record 23 of Set 12 | selje
# Processing Record 24 of Set 12 | umm kaddadah
# Processing Record 25 of Set 12 | lazaro cardenas
# Processing Record 26 of Set 12 | krasyukovskaya
# Processing Record 27 of Set 12 | san quintin
# Processing Record 28 of Set 12 | kathu
# Processing Record 29 of Set 12 | hambantota
# Processing Record 30 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 31 of Set 12 | puebloviejo
# Processing Record 32 of Set 12 | college
# Processing Record 33 of Set 12 | pierre
# Processing Record 34 of Set 12 | xghajra
# City not found. Skipping...
# Processing Record 35 of Set 12 | san borja
# Processing Record 36 of Set 12 | feijo
# Processing Record 37 of Set 12 | ixtapa
# Processing Record 38 of Set 12 | snasa
# Processing Record 39 of Set 12 | necochea
# Processing Record 40 of Set 12 | tkvarcheli
# City not found. Skipping...
# Processing Record 41 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 12 | moroto
# Processing Record 43 of Set 12 | aykhal
# Processing Record 44 of Set 12 | payo
# Processing Record 45 of Set 12 | eston
# Processing Record 46 of Set 12 | oosterzele
# Processing Record 47 of Set 12 | timaru
# Processing Record 48 of Set 12 | lage
# Processing Record 49 of Set 12 | ballina
# Processing Record 50 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 13 | makueni
# Processing Record 2 of Set 13 | wahpeton
# Processing Record 3 of Set 13 | yeppoon
# Processing Record 4 of Set 13 | ewa beach
# Processing Record 5 of Set 13 | krasnoslobodsk
# Processing Record 6 of Set 13 | stuttgart
# Processing Record 7 of Set 13 | zalesovo
# Processing Record 8 of Set 13 | hire
# City not found. Skipping...
# Processing Record 9 of Set 13 | campos belos
# Processing Record 10 of Set 13 | pecos
# Processing Record 11 of Set 13 | san andres
# Processing Record 12 of Set 13 | benton harbor
# Processing Record 13 of Set 13 | bubaque
# Processing Record 14 of Set 13 | nyakabindi
# Processing Record 15 of Set 13 | garowe
# Processing Record 16 of Set 13 | tilhar
# Processing Record 17 of Set 13 | kushiro
# Processing Record 18 of Set 13 | jian
# Processing Record 19 of Set 13 | yuanping
# Processing Record 20 of Set 13 | saint-pierre
# Processing Record 21 of Set 13 | charyshskoye
# Processing Record 22 of Set 13 | sungaipenuh
# Processing Record 23 of Set 13 | bazaliya
# Processing Record 24 of Set 13 | chicama
# Processing Record 25 of Set 13 | fereydun kenar
# Processing Record 26 of Set 13 | pachino
# Processing Record 27 of Set 13 | rehoboth
# Processing Record 28 of Set 13 | mollendo
# Processing Record 29 of Set 13 | cabedelo
# Processing Record 30 of Set 13 | along
# Processing Record 31 of Set 13 | trelew
# Processing Record 32 of Set 13 | port hawkesbury
# Processing Record 33 of Set 13 | kachiry
# Processing Record 34 of Set 13 | poya
# Processing Record 35 of Set 13 | tucupita
# Processing Record 36 of Set 13 | raudeberg
# Processing Record 37 of Set 13 | benguela
# Processing Record 38 of Set 13 | newcastle
# Processing Record 39 of Set 13 | sidi bu zayd
# City not found. Skipping...
# Processing Record 40 of Set 13 | paita
# Processing Record 41 of Set 13 | belmonte
# Processing Record 42 of Set 13 | agirish
# Processing Record 43 of Set 13 | vredendal
# Processing Record 44 of Set 13 | hailar
# Processing Record 45 of Set 13 | santa quiteria
# Processing Record 46 of Set 13 | saint-joseph
# Processing Record 47 of Set 13 | grenfell
# Processing Record 48 of Set 13 | mulege
# Processing Record 49 of Set 13 | bozova
# Processing Record 50 of Set 13 | erzin
# Processing Record 1 of Set 14 | nome
# Processing Record 2 of Set 14 | manado
# Processing Record 3 of Set 14 | rizhao
# Processing Record 4 of Set 14 | mayo
# Processing Record 5 of Set 14 | tuy hoa
# Processing Record 6 of Set 14 | turki
# Processing Record 7 of Set 14 | caravelas
# Processing Record 8 of Set 14 | dhidhdhoo
# Processing Record 9 of Set 14 | gamba
# Processing Record 10 of Set 14 | merta
# Processing Record 11 of Set 14 | lasa
# Processing Record 12 of Set 14 | goundi
# Processing Record 13 of Set 14 | sulya
# Processing Record 14 of Set 14 | gravdal
# Processing Record 15 of Set 14 | cuiluan
# Processing Record 16 of Set 14 | luena
# Processing Record 17 of Set 14 | sao jose da coroa grande
# Processing Record 18 of Set 14 | malabo
# Processing Record 19 of Set 14 | alofi
# Processing Record 20 of Set 14 | mazagao
# Processing Record 21 of Set 14 | lichuan
# Processing Record 22 of Set 14 | alekseyevka
# Processing Record 23 of Set 14 | north bend
# Processing Record 24 of Set 14 | coihaique
# Processing Record 25 of Set 14 | qingdao
# Processing Record 26 of Set 14 | kendari
# Processing Record 27 of Set 14 | andenes
# Processing Record 28 of Set 14 | yurimaguas
# Processing Record 29 of Set 14 | arica
# Processing Record 30 of Set 14 | bedesa
# Processing Record 31 of Set 14 | yatou
# Processing Record 32 of Set 14 | whitehorse
# Processing Record 33 of Set 14 | praia da vitoria
# Processing Record 34 of Set 14 | ulaanbaatar
# Processing Record 35 of Set 14 | naushki
# Processing Record 36 of Set 14 | xichang
# Processing Record 37 of Set 14 | benavente
# Processing Record 38 of Set 14 | tarpon springs
# Processing Record 39 of Set 14 | mwinilunga
# Processing Record 40 of Set 14 | podyuga
# Processing Record 41 of Set 14 | vanimo
# Processing Record 42 of Set 14 | mwense
# Processing Record 43 of Set 14 | novopskov
# Processing Record 44 of Set 14 | ust-maya
# Processing Record 45 of Set 14 | ye
# City not found. Skipping...
# Processing Record 46 of Set 14 | muros
# Processing Record 47 of Set 14 | asfi
# Processing Record 48 of Set 14 | lamu
# Processing Record 49 of Set 14 | ust-koksa
# Processing Record 50 of Set 14 | yerbogachen
# Processing Record 1 of Set 15 | kachikau
# City not found. Skipping...
# Processing Record 2 of Set 15 | dwarka
# Processing Record 3 of Set 15 | ormara
# Processing Record 4 of Set 15 | hannibal
# Processing Record 5 of Set 15 | preeceville
# Processing Record 6 of Set 15 | boca do acre
# Processing Record 7 of Set 15 | coria
# Processing Record 8 of Set 15 | dong hoi
# Processing Record 9 of Set 15 | crestview
# Processing Record 10 of Set 15 | awbari
# Processing Record 11 of Set 15 | morgan city
# Processing Record 12 of Set 15 | tikapur
# Processing Record 13 of Set 15 | namtsy
# Processing Record 14 of Set 15 | arroyo
# Processing Record 15 of Set 15 | kamaishi
# Processing Record 16 of Set 15 | kualakapuas
# Processing Record 17 of Set 15 | kailua
# Processing Record 18 of Set 15 | pachperwa
# Processing Record 19 of Set 15 | togul
# Processing Record 20 of Set 15 | palenque
# Processing Record 21 of Set 15 | verkhoyansk
# Processing Record 22 of Set 15 | bari
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Araouane  18.90   -3.53     96.58        30           2        8.55
# 1    Rio Grande -32.03  -52.10     57.99        88           0        4.00
# 2        Avarua -21.21 -159.78     77.00        65           6        8.05
# 3     Carnarvon -24.87  113.63     59.00        82           0       13.87
# 4         Tiksi  71.69  128.87     40.10        75          96       12.03
# 5   Port Alfred -33.59   26.89     57.65        82          61       10.25
# 6  Puerto Ayora  -0.74  -90.35     69.01        82          71        3.00
# 7       Ushuaia -54.80  -68.30     32.00        93          75       14.99
# 8         Pisco -13.70  -76.22     62.60        77          90        4.70
# 9        Laguna  38.42 -121.42     97.00        12           1       10.29
#
#   Country      Description                 Date
# 0      ML        clear sky  2020-08-23 23:21:03
# 1      BR        clear sky  2020-08-23 23:25:25
# 2      CK        clear sky  2020-08-23 23:25:07
# 3      AU        clear sky  2020-08-23 23:24:57
# 4      RU  overcast clouds  2020-08-23 23:25:25
# 5      ZA    broken clouds  2020-08-23 23:25:26
# 6      EC    broken clouds  2020-08-23 23:25:26
# 7      AR      shower rain  2020-08-23 23:22:52
# 8      PE  overcast clouds  2020-08-23 23:22:20
# 9      US             haze  2020-08-23 23:25:26

# %%
#re-ordering the columns to improve readability
New_Column_Order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[New_Column_Order]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-1bb25b85206a> in <module>
#       2 output_data_file = "Weather_Database/Weather_Database.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
#     190             close = True
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/Weather_Database.csv'
